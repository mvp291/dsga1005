# %%
import code.independence_test as it
import code.additive_noise as an
import numpy as np
import numpy.random as rn

# %%
import code.hsic as hs

# %%
n=200
uni = rn.uniform(0,10,n)
exp = rn.exponential(7,n)
gamma = rn.gamma(10,1,n)
log = rn.logistic(10,0.5,n)
n_Y = np.random.normal(0,0.4,n)
n_L = np.random.normal(0,0.5,n)
#Y = uni + exp + gamma + log + n_Y
Y = gamma + log + n_Y
leak = Y + n_L

# %%
X = np.stack([gamma,log, leak],axis=1)

# %%
an.ANM_algorithm(X,Y)
# Out:
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 202.515)
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 193.577)
# Matile 0.0101422717656 0.00782576262096
# -1

# %%
hsic = it.HSIC_b(exp,Y)
hsic.empirical_test()
# Out:
# 0.0015719331919769274

# %%
X = np.random.uniform(0,10,1000)
n_Y = np.random.normal(0,1,1000)
#Y= X 
Y = n_Y

# %%
hsic = it.HSIC_b(X,Y)

# %%
hsic.empirical_test()
# Out:
# 0.00044719086949533265

# %%
hsic.alpha()
# Out:
# 2.2857938797601257e-05

# %%
hsic.beta()
# Out:
# 23112.678901271611

# %%
hsic.p_value
# Out:
# 0.0002348543990698948

# %%
a = {1:'uno', 2:'dos', 3:'tres'}

# %%
for i in a:
    print i, a[i]
# Out:
# 1 uno
# 2 dos
# 3 tres

# %%
from sklearn.metrics.pairwise import rbf_kernel, laplacian_kernel

# %%
rbf_kernel?

# %%
len(str(20))
# Out:
# 2

# %%
range(59,105)
# Out:
# [59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104]

# %%
accuracy = list()
for i in range(105):
    pair = str(i+1)
    if len(pair)==1:
        pair = '000'+ pair
    if len(pair)==2:
        pair = '00'+ pair
    if len(pair)==3:
        pair = '0'+ pair
    if pair != '0047' and pair != '0060' and pair != '0061':
        data = np.loadtxt('./data/pair'+pair+'.txt')
        if data.shape[0]>500:
            data = data[0:500]
        print 'pair', pair
        print 'n_columns',data.shape[1]
        if data.shape[1]==2:
            X = data[:,0]
            Y = data[:,1]
            dire = an.ANM_algorithm2(X,Y)
            if dire == directions[i]:
                accuracy.append(1)
            else:
                accuracy.append(0)    
        else:
            continue
# Out:
# pair 0001
# n_columns 2
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 243.795)
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 1507.193)
# Matile 0.00303735991882 0.00548623414462
# pair 0002
# n_columns 2
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 1578.131)
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 1603.183)
# Matile 0.00852389616359 0.00854505682045
# pair 0003
# n_columns 2
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 435.725)
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 469.056)
# Matile 0.00548615761663 0.00498043839901
# pair 0004
# n_columns 2
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 1467.37)
# Number of line searches 40
# ('Optimized negative log marginal likelihood:', 1693.579)
# Matile 0.00852355342941 0.00854509204821
# pair 0005
# ...

# %%
np.array(accuracy).sum()/float(len(accuracy))
# Out:
# 0.5376344086021505

# %%
np.array(accuracy).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8705c6c076df> in <module>()
# ----> 1 np.array(accuracy).shape
#
# NameError: name 'accuracy' is not defined

# %%
pair = np.loadtxt('./data/pair0006.txt')
pair[:,0][0:500].shape
# Out:
# (500,)

# %%
metadata = np.loadtxt('./pairmeta.txt')

# %%
directions = metadata[:,3]-metadata[:,2]

# %%
directions.shape
# Out:
# (105,)

# %%
directions.shape
# Out:
# (105,)

# %%
import modshogun
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-a6f93927f87b> in <module>()
# ----> 1 import modshogun
#
# ImportError: No module named 'modshogun'
